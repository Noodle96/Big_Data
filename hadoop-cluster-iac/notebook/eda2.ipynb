# %%
from pathlib import Path
from typing import List

import pandas as pd
import matplotlib.pyplot as plt

# %%
long_df_path: Path = Path(
    "../data/official_onpe/processed/resultados_presidencial_long.tsv"
)

long_df: pd.DataFrame = pd.read_csv(long_df_path, sep='\t')

long_df.head()
# Out:
#   TIPO DE ELECCIÓN ÁMBITO REGIÓN / CONTINENTE PROVINCIA / PAÍS  \
# 0     PRESIDENCIAL   PERÚ            AMAZONAS      CHACHAPOYAS
# 1     PRESIDENCIAL   PERÚ            AMAZONAS      CHACHAPOYAS
# 2     PRESIDENCIAL   PERÚ            AMAZONAS      CHACHAPOYAS
# 3     PRESIDENCIAL   PERÚ            AMAZONAS      CHACHAPOYAS
# 4     PRESIDENCIAL   PERÚ            AMAZONAS      CHACHAPOYAS
#
#   DISTRITO / CIUDAD               LOCAL DE VOTACIÓN  NÚMERO DE MESA  \
# 0       CHACHAPOYAS  IE 18288 ISABEL LYNCH DE RUBIO               1
# 1       CHACHAPOYAS  IE 18288 ISABEL LYNCH DE RUBIO               2
# 2       CHACHAPOYAS  IE 18288 ISABEL LYNCH DE RUBIO               3
# 3       CHACHAPOYAS  IE 18288 ISABEL LYNCH DE RUBIO               4
# 4       CHACHAPOYAS  IE 18288 ISABEL LYNCH DE RUBIO               5
#
#   ESTADO DEL ACTA  ELECTORES HÁBILES         ORGANIZACION_POLITICA  VOTOS
# 0   Contabilizada                230  ALIANZA ELECTORAL VENCEREMOS    4.0
# ...

# %%
long_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513366 entries, 0 to 3513365
# Data columns (total 11 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   TIPO DE ELECCIÓN       object
#  1   ÁMBITO                 object
#  2   REGIÓN / CONTINENTE    object
#  3   PROVINCIA / PAÍS       object
#  4   DISTRITO / CIUDAD      object
#  5   LOCAL DE VOTACIÓN      object
#  6   NÚMERO DE MESA         int64
#  7   ESTADO DEL ACTA        object
#  8   ELECTORES HÁBILES      int64
#  9   ORGANIZACION_POLITICA  object
#  10  VOTOS                  float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 294.9+ MB
