# %%
from pathlib import Path

import pandas as pd
import pyarrow.parquet as pq

# %%
project_root: Path = Path("..").resolve()

parquet_path: Path = (
    project_root
    / "data"
    / "taxi"
    / "raw"
    / "yellow_tripdata_2024-03.parquet"
)

parquet_path
# Out:
# PosixPath('/home/russell/ssd/code/Big_Data/hive-emr-lab/data/taxi/raw/yellow_tripdata_2024-03.parquet')

# %%
file_size_mb: float = parquet_path.stat().st_size / (1024 ** 2)

print(f"Archivo: {parquet_path.name}")
print(f"Tamaño: {file_size_mb:.2f} MB")
# Out:
# Archivo: yellow_tripdata_2024-03.parquet
# Tamaño: 57.30 MB

# %%
parquet_file: pq.ParquetFile = pq.ParquetFile(parquet_path)

print(f"Número de filas: {parquet_file.metadata.num_rows}")
print(f"Número de columnas: {parquet_file.metadata.num_columns}")
print(f"Número de row groups: {parquet_file.metadata.num_row_groups}")
# Out:
# Número de filas: 3582628
# Número de columnas: 19
# Número de row groups: 4

# %%
schema = parquet_file.schema_arrow
schema
# Out:
# VendorID: int32
# tpep_pickup_datetime: timestamp[us]
# tpep_dropoff_datetime: timestamp[us]
# passenger_count: int64
# trip_distance: double
# RatecodeID: int64
# store_and_fwd_flag: large_string
# PULocationID: int32
# DOLocationID: int32
# payment_type: int64
# fare_amount: double
# extra: double
# mta_tax: double
# tip_amount: double
# tolls_amount: double
# improvement_surcharge: double
# total_amount: double
# congestion_surcharge: double
# Airport_fee: double

# %%
df_sample: pd.DataFrame = pd.read_parquet(parquet_path).head(10)

df_sample
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-03-01 00:18:51   2024-03-01 00:23:45              0.0
# 1         1  2024-03-01 00:26:00   2024-03-01 00:29:06              0.0
# 2         2  2024-03-01 00:09:22   2024-03-01 00:15:24              1.0
# 3         2  2024-03-01 00:33:45   2024-03-01 00:39:34              1.0
# 4         1  2024-03-01 00:05:43   2024-03-01 00:26:22              0.0
# 5         2  2024-03-01 00:50:42   2024-03-01 01:10:40              1.0
# 6         2  2024-03-01 00:08:23   2024-03-01 00:17:53              1.0
# 7         2  2024-03-01 00:24:58   2024-03-01 00:30:31              1.0
# 8         2  2024-03-01 00:49:40   2024-03-01 01:01:25              1.0
# 9         1  2024-03-01 00:21:43   2024-03-01 00:24:44              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.30         1.0                  N           142           239
# 1           1.10         1.0                  N           238            24
# 2           0.86         1.0                  N           263            75
# 3           0.82         1.0                  N           164           162
# 4           4.90         1.0                  N           263             7
# 5           5.04         1.0                  N           238           159
# 6           2.15         1.0                  N           161           141
# 7           1.10         1.0                  N           236           237
# 8           2.78         1.0                  N           161           114
# 9           0.30         1.0                  N           237           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          8.6    3.5      0.5        2.70           0.0
# 1             1          7.2    3.5      0.5        3.00           0.0
# 2             2          7.9    1.0      0.5        0.00           0.0
# 3             1          7.9    1.0      0.5        1.29           0.0
# 4             2         25.4    3.5      0.5        0.00           0.0
# 5             2         25.4    1.0      0.5        0.00           0.0
# 6             1         12.1    1.0      0.5        5.13           0.0
# 7             1          8.6    1.0      0.5        2.04           0.0
# 8             1         14.9    1.0      0.5        2.00           0.0
# 9             2          5.1    3.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         16.30                   2.5          0.0
# 1                    1.0         15.20                   2.5          0.0
# 2                    1.0         10.40                   0.0          0.0
# 3                    1.0         14.19                   2.5          0.0
# 4                    1.0         30.40                   2.5          0.0
# 5                    1.0         27.90                   0.0          0.0
# 6                    1.0         22.23                   2.5          0.0
# 7                    1.0         15.64                   2.5          0.0
# 8                    1.0         21.90                   2.5          0.0
# 9                    1.0         10.10                   2.5          0.0

# %% [markdown]
# ## Comparacion de columnas entre 2023 y 2024 de Yellow Taxi Trip Record

# %%
from pathlib import Path
import pandas as pd

file_2023: Path = Path("../data/taxi/raw/yellow_tripdata_2023-01.parquet")
file_2024: Path = Path("../data/taxi/raw/yellow_tripdata_2024-01.parquet")

df_2023 = pd.read_parquet(file_2023, engine="pyarrow")
df_2024 = pd.read_parquet(file_2024, engine="pyarrow")

cols_2023 = set(df_2023.columns)
cols_2024 = set(df_2024.columns)

print("Solo en 2023:")
print(sorted(cols_2023 - cols_2024))

print("\nSolo en 2024:")
print(sorted(cols_2024 - cols_2023))

print("\nMismas columnas:")
print(cols_2023 == cols_2024)
# Out:
# Solo en 2023:
# ['airport_fee']
#
# Solo en 2024:
# ['Airport_fee']
#
# Mismas columnas:
# False

# %%
print(df_2023["airport_fee"].dtype)

print(df_2024["Airport_fee"].dtype)
# Out:
# float64
# float64

# %%
print(df_2023.dtypes)

print(df_2024.dtypes)
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# dtype: object

# %%
for col in sorted(set(df_2023.columns) & set(df_2024.columns)):
    if df_2023[col].dtype != df_2024[col].dtype:
        print(
            col,
            df_2023[col].dtype,
            df_2024[col].dtype
        )
# Out:
# DOLocationID int64 int32
# PULocationID int64 int32
# VendorID int64 int32
